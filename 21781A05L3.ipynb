# %% [markdown]
# # Task1-Create a pandas dataframe (DataFrame name as 'df') with numpy random values (4 features and 4 observation)

# %%
import numpy as np
import pandas as pd

random_data = np.random.randn(4, 4)


random_data
# Out:
# array([[ 0.09588731, -1.49333951,  0.18744265, -1.65128792],
#        [-1.33871488, -1.29243685,  1.09412252,  1.23028713],
#        [ 0.40433308, -0.78994912, -0.25911835,  0.40182334],
#        [ 1.29719001,  1.23284161,  0.01949652, -1.03695908]])

# %% [markdown]
# # Task - 2 Rename the task - 1 'df' dataframe column names to 'Random value 1', 'Random value 2', 'Random value 3' & 'Random value 4'

# %%
df = pd.DataFrame(random_data, columns=['Random value 1', 'Random value 2', 'Random value 3', 'Random value 4'])
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.095887       -1.493340        0.187443       -1.651288
# 1       -1.338715       -1.292437        1.094123        1.230287
# 2        0.404333       -0.789949       -0.259118        0.401823
# 3        1.297190        1.232842        0.019497       -1.036959

# %% [markdown]
# # Task - 3 Find the descriptive statistics of the 'df' dataframe.

# %%
ds=df.describe()
ds
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.114674       -0.585721        0.260486       -0.264034
# std          1.094675        1.247945        0.585477        1.316339
# min         -1.338715       -1.493340       -0.259118       -1.651288
# 25%         -0.262763       -1.342663       -0.050157       -1.190541
# 50%          0.250110       -1.041193        0.103470       -0.317568
# 75%          0.627547       -0.284251        0.414113        0.608939
# max          1.297190        1.232842        1.094123        1.230287

# %% [markdown]
# # Task - 4 Check for the null values in 'df' and find the data type of the columns.

# %%
nullvalues=df.isnull().sum()
nullvalues
# Out:
# Random value 1    0
# Random value 2    0
# Random value 3    0
# Random value 4    0
# dtype: int64

# %% [markdown]
# # Task - 5 Display the 'Random value 2' & 'Random value 3' columns with location method and index location method.

# %%
new_values=df.iloc[:, [1, 2]]
new_values
# Out:
#    Random value 2  Random value 3
# 0       -1.493340        0.187443
# 1       -1.292437        1.094123
# 2       -0.789949       -0.259118
# 3        1.232842        0.019497
